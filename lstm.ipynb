# %%
from datasets import load_dataset
dataset = load_dataset("dair-ai/emotion")

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, LSTM, Dense, Dropout

# %%
X_train = dataset["train"]["text"]
y_train = dataset["train"]["label"]

X_val = dataset["validation"]["text"]
y_val = dataset["validation"]["label"]

# %%
tokenizer = Tokenizer(num_words=20000, oov_token="<OOV>")
tokenizer.fit_on_texts(X_train)

X_train_seq = tokenizer.texts_to_sequences(X_train)
X_val_seq = tokenizer.texts_to_sequences(X_val)

# %%
max_len = 100

X_train_pad = pad_sequences(
    X_train_seq, maxlen=max_len, padding="post"
)

X_val_pad = pad_sequences(
    X_val_seq, maxlen=max_len, padding="post"
)

# %%
model = Sequential([
    Embedding(input_dim=20000, output_dim=128, input_length=max_len),
    LSTM(128),
    Dropout(0.5),
    Dense(6, activation="softmax")
])

model.compile(
    optimizer="adam",
    loss="sparse_categorical_crossentropy",
    metrics=["accuracy"]
)

model.summary()
# Out:
# d:\nlp\venv\Lib\site-packages\keras\src\layers\core\embedding.py:97: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding (Embedding)           │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm (LSTM)                     │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ ?                      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ ?                      │   0 (unbuilt) │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 0 (0.00 B)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
import numpy as np

y_train = np.array(y_train)
y_val = np.array(y_val)

# %%
history = model.fit(
    X_train_pad,
    y_train,
    epochs=10,
    batch_size=64,
    validation_data=(X_val_pad, y_val)
)
# Out:
# Epoch 1/10
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 33s 131ms/step - accuracy: 0.3316 - loss: 1.5801 - val_accuracy: 0.3520 - val_loss: 1.5820
# Epoch 2/10
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 38s 153ms/step - accuracy: 0.3304 - loss: 1.5797 - val_accuracy: 0.3520 - val_loss: 1.5843
# Epoch 3/10
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 39s 155ms/step - accuracy: 0.3334 - loss: 1.5784 - val_accuracy: 0.3520 - val_loss: 1.5807
# Epoch 4/10
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 38s 150ms/step - accuracy: 0.3335 - loss: 1.5786 - val_accuracy: 0.3520 - val_loss: 1.5820
# Epoch 5/10
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 38s 152ms/step - accuracy: 0.3343 - loss: 1.5794 - val_accuracy: 0.3520 - val_loss: 1.5814
# Epoch 6/10
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 38s 150ms/step - accuracy: 0.3356 - loss: 1.5786 - val_accuracy: 0.3520 - val_loss: 1.5805
# Epoch 7/10
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 38s 152ms/step - accuracy: 0.3341 - loss: 1.5783 - val_accuracy: 0.3520 - val_loss: 1.5812
# Epoch 8/10
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 40s 161ms/step - accuracy: 0.3344 - loss: 1.5779 - val_accuracy: 0.3520 - val_loss: 1.5804
# Epoch 9/10
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 39s 156ms/step - accuracy: 0.3338 - loss: 1.5775 - val_accuracy: 0.3520 - val_loss: 1.5833
# Epoch 10/10
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 39s 155ms/step - accuracy: 0.3348 - loss: 1.5776 - val_accuracy: 0.3520 - val_loss: 1.5829

# %%
val_loss, val_acc = model.evaluate(X_val_pad, y_val)
print("Validation Accuracy:", val_acc)
# Out:
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 3s 41ms/step - accuracy: 0.3520 - loss: 1.5829
# Validation Accuracy: 0.35199999809265137
